# %%
class carselection:
    def __init__(self):
        pass

    def details1(self):
        print("Great Choice!! For Brand: Hyundai")
        print("You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Hyundai i20
        2. Hyundai Creta
        3. Hyundai Venue
        4. Hyundai Verna
        5. Hyundai Alcazar
        ''')
        print("Do You want to show details of above Models: ")
        opt = input("Enter your Response (Yes/No) Only: ")
        if opt.lower() == 'yes' or opt.lower() == 'y':
            value = int(input("Choose model number from above list: "))
            if value == 1:
                print('''
                --- Hyundai i20 ---
                Engine: 1.2L Petrol / 1.5L Diesel
                Mileage: 20 km/l
                Price: ₹7.5 - ₹11.5 lakh
                Type: Hatchback
                ''')
            elif value == 2:
                print('''
                --- Hyundai Creta ---
                Engine: 1.5L Petrol / 1.5L Diesel / 1.4L Turbo
                Mileage: 17 km/l
                Price: ₹11 - ₹20 lakh
                Type: SUV
                ''')
            elif value == 3:
                print('''
                --- Hyundai Venue ---
                Engine: 1.2L Petrol / 1.5L Diesel
                Mileage: 18 km/l
                Price: ₹8 - ₹13 lakh
                Type: Compact SUV
                ''')
            elif value == 4:
                print('''
                --- Hyundai Verna ---
                Engine: 1.5L Petrol / 1.5L Diesel
                Mileage: 18.6 km/l
                Price: ₹11 - ₹17 lakh
                Type: Sedan
                ''')
            elif value == 5:
                print('''
                --- Hyundai Alcazar ---
                Engine: 2.0L Petrol / 1.5L Diesel
                Mileage: 17.5 km/l
                Price: ₹16 - ₹21 lakh
                Type: 7-Seater SUV
                ''')
            else:
                print("Invalid Input!")
        else:
            print("Thank You")

    def details2(self):
        print("Great Choice!! You Go with Old brand")
        print("Here are the TOP FIVE CARS OF Maruti You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Maruti Alto 800
        2. Maruti Swift
        3. Maruti Baleno
        4. Maruti Dzire
        5. Maruti Brezza
        ''')

        print("Do You want to show details of above Models: ")
        model = input("Enter your Response (Yes/No) Only: ")
        if model.lower() == 'yes' or model.lower() == 'y':
            model = int(input("Choose model number from above list: "))
            if model == 1:
                print('''
                --- Maruti Alto 800 ---
                Engine: 0.8L Petrol
                Mileage: 22 km/l
                Price: ₹3.5 - ₹5 lakh
                Type: Entry-level Hatchback
                ''')
            elif model == 2:
                print('''
                --- Maruti Swift ---
                Engine: 1.2L Petrol
                Mileage: 22.4 km/l
                Price: ₹6 - ₹9 lakh
                Type: Hatchback
                ''')
            elif model == 3:
                print('''
                --- Maruti Baleno ---
                Engine: 1.2L Petrol
                Mileage: 22.9 km/l
                Price: ₹6.6 - ₹9.8 lakh
                Type: Premium Hatchback
                ''')
            elif model == 4:
                print('''
                --- Maruti Dzire ---
                Engine: 1.2L Petrol
                Mileage: 23 km/l
                Price: ₹6.5 - ₹9.5 lakh
                Type: Sedan
                ''')
            elif model == 5:
                print('''
                --- Maruti Brezza ---
                Engine: 1.5L Petrol
                Mileage: 19 km/l
                Price: ₹8.5 - ₹14 lakh
                Type: Compact SUV
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")

    def details3(self):
        print("Great Choice!! You Go with Suzuki")
        print("Here are the TOP FIVE CARS OF Suzuki (Parent Company of Maruti) You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Suzuki Swift
        2. Suzuki Baleno
        3. Suzuki Celerio
        4. Suzuki Vitara
        5. Suzuki Jimny
        ''')

        print("Do You want to show details of above Models: ")
        model = input("Enter your Response (Yes/No) Only: ")
        if model.lower() == 'yes' or model.lower() == 'y':
            value = int(input("Choose model number from above list: "))
            if value == 1:
                print('''
                --- Suzuki Swift ---
                Engine: 1.2L Petrol
                Mileage: 22.4 km/l
                Price: ₹6 - ₹9 lakh
                Type: Hatchback
                ''')
            elif value == 2:
                print('''
                --- Suzuki Baleno ---
                Engine: 1.2L Petrol
                Mileage: 22.9 km/l
                Price: ₹6.6 - ₹9.8 lakh
                Type: Premium Hatchback
                ''')
            elif value == 3:
                print('''
                --- Suzuki Celerio ---
                Engine: 1.0L Petrol
                Mileage: 25 km/l
                Price: ₹5 - ₹7 lakh
                Type: Compact Hatchback
                ''')
            elif value == 4:
                print('''
                --- Suzuki Vitara ---
                Engine: 1.5L Petrol / 1.5L Hybrid
                Mileage: 19 km/l
                Price: ₹10 - ₹15 lakh
                Type: SUV
                ''')
            elif value == 5:
                print('''
                --- Suzuki Jimny ---
                Engine: 1.5L Petrol
                Mileage: 16 km/l
                Price: ₹12 - ₹15 lakh
                Type: Off-Road SUV (4x4)
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")

    def details4(self):
        print("Great Choice!! You Go with Nissan")
        print("Here are the TOP FIVE CARS OF Nissan You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Nissan Magnite
        2. Nissan Kicks
        3. Nissan Sunny
        4. Nissan Micra
        5. Nissan Terrano
        ''')
           

        print("Do you want to show details of the above Models?")
        opt = input("Enter your Response (Yes/No) Only: ")

        if opt.lower() == 'yes' or opt.lower() == 'y':
            value = int(input("Choose model number from above list: "))
            if value == 1:
                print('''
                --- Nissan Magnite ---
                Engine: 1.0L Petrol / 1.0L Turbo Petrol
                Mileage: 18-20 km/l
                Price: ₹6 - ₹11 lakh
                Type: Compact SUV
                ''')
            elif value == 2:
                print('''
                --- Nissan Kicks ---
                Engine: 1.5L Petrol / 1.3L Turbo Petrol
                Mileage: 16-18 km/l
                Price: ₹9 - ₹14 lakh
                Type: SUV
                ''')
            elif value == 3:
                print('''
                --- Nissan Sunny ---
                Engine: 1.5L Petrol
                Mileage: 19 km/l
                Price: ₹8 - ₹10 lakh
                Type: Sedan
                ''')
            elif value == 4:
                print('''
                --- Nissan Micra ---
                Engine: 1.2L Petrol
                Mileage: 20 km/l
                Price: ₹6 - ₹8 lakh
                Type: Hatchback
                ''')
            elif value == 5:
                print('''
                --- Nissan Terrano ---
                Engine: 1.6L Petrol / 1.5L Diesel
                Mileage: 17 km/l
                Price: ₹10 - ₹14 lakh
                Type: SUV
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")

        

    def details5(self):
        print("Great Choice!! You Go with Honda")
        print("Here are the TOP FIVE CARS OF Honda You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Honda Amaze
        2. Honda City
        3. Honda Jazz
        4. Honda WR-V
        5. Honda Elevate
        ''')

        print("Do you want to show details of the above Models?")
        opt = input("Enter your Response (Yes/No) Only: ")

        if opt.lower() == 'yes' or opt.lower() == 'y':
            value = int(input("Choose model number from above list: "))

            if value == 1:
                print('''
                --- Honda Amaze ---
                Engine: 1.2L Petrol / 1.5L Diesel
                Mileage: 18.6 - 24.7 km/l
                Price: ₹7 - ₹10 lakh
                Type: Compact Sedan
                ''')
            elif value == 2:
                print('''
                --- Honda City ---
                Engine: 1.5L Petrol / 1.5L Hybrid
                Mileage: 17.8 - 27 km/l
                Price: ₹12 - ₹16 lakh
                Type: Mid-size Sedan
                ''')
            elif value == 3:
                print('''
                --- Honda Jazz ---
                Engine: 1.2L Petrol
                Mileage: 17 - 18 km/l
                Price: ₹8 - ₹10 lakh
                Type: Premium Hatchback
                ''')
            elif value == 4:
                print('''
                --- Honda WR-V ---
                Engine: 1.2L Petrol / 1.5L Diesel
                Mileage: 17 - 23 km/l
                Price: ₹9 - ₹11 lakh
                Type: Compact Crossover
                ''')
            elif value == 5:
                print('''
                --- Honda Elevate ---
                Engine: 1.5L Petrol
                Mileage: 16 - 17 km/l
                Price: ₹11 - ₹16 lakh
                Type: SUV
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")


    def details6(self):
        print("Great Choice!! You Go with BMW")
        print("Here are the TOP FIVE CARS OF BMW You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. BMW X1
        2. BMW X3
        3. BMW X5
        4. BMW 3 Series
        5. BMW 7 Series
        ''')

        print("Do you want to show details of the above Models?")
        opt = input("Enter your Response (Yes/No) Only: ")

        if opt.lower() == 'yes' or opt.lower() == 'y':
            value = int(input("Choose model number from above list: "))

            if value == 1:
                print('''
                --- BMW X1 ---
                Engine: 2.0L Petrol / 2.0L Diesel
                Mileage: 16 km/l
                Price: ₹48 - ₹55 lakh
                Type: Luxury Compact SUV
                ''')
            elif value == 2:
                print('''
                --- BMW X3 ---
                Engine: 2.0L Petrol / 2.0L Diesel
                Mileage: 14 km/l
                Price: ₹68 - ₹75 lakh
                Type: Mid-size Luxury SUV
                ''')
            elif value == 3:
                print('''
                --- BMW X5 ---
                Engine: 3.0L Petrol / 3.0L Diesel
                Mileage: 12 km/l
                Price: ₹1.0 - ₹1.2 crore
                Type: Premium SUV
                ''')
            elif value == 4:
                print('''
                --- BMW 3 Series ---
                Engine: 2.0L Petrol / 2.0L Diesel
                Mileage: 16 km/l
                Price: ₹72 - ₹85 lakh
                Type: Luxury Sedan
                ''')
            elif value == 5:
                print('''
                --- BMW 7 Series ---
                Engine: 3.0L Petrol / 3.0L Diesel / Hybrid
                Mileage: 10 - 12 km/l
                Price: ₹1.8 - ₹2.0 crore
                Type: Flagship Luxury Sedan
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")


    def details7(self):
        print("Great Choice!! You Go with Mercedes")
        print("Here are the TOP FIVE CARS OF Mercedes-Benz You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Mercedes A-Class
        2. Mercedes C-Class
        3. Mercedes E-Class
        4. Mercedes GLA
        5. Mercedes GLC
        ''')
        print("Do you want to show details of the above Models?")
        opt = input("Enter your Response (Yes/No) Only: ")

        if opt.lower() == 'yes' or opt.lower() == 'y':
            value = int(input("Choose model number from above list: "))

            if value == 1:
                print('''
                --- Mercedes A-Class ---
                Engine: 1.3L Turbo Petrol / 2.0L Diesel
                Mileage: 18 km/l
                Price: ₹46 - ₹50 lakh
                Type: Entry-Level Luxury Sedan
                ''')
            elif value == 2:
                print('''
                --- Mercedes C-Class ---
                Engine: 1.5L Turbo Petrol / 2.0L Diesel
                Mileage: 16 km/l
                Price: ₹60 - ₹70 lakh
                Type: Executive Luxury Sedan
                ''')
            elif value == 3:
                print('''
                --- Mercedes E-Class ---
                Engine: 2.0L Petrol / 3.0L Diesel
                Mileage: 13 - 15 km/l
                Price: ₹75 lakh - ₹1.0 crore
                Type: Luxury Sedan
                ''')
            elif value == 4:
                print('''
                --- Mercedes GLA ---
                Engine: 1.3L Turbo Petrol / 2.0L Diesel
                Mileage: 15 km/l
                Price: ₹50 - ₹60 lakh
                Type: Compact Luxury SUV
                ''')
            elif value == 5:
                print('''
                --- Mercedes GLC ---
                Engine: 2.0L Petrol / 2.0L Diesel
                Mileage: 13 km/l
                Price: ₹75 - ₹90 lakh
                Type: Mid-size Luxury SUV
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")


    def details8(self):
        print("Great Choice!! You Go with Ford")
        print("Here are the TOP FIVE CARS OF Ford You can go with the following car models for your selected brand")
        print("-----------------------------------------------")
        print('''
        1. Ford EcoSport
        2. Ford Endeavour
        3. Ford Figo
        4. Ford Aspire
        5. Ford Mustang
        ''')
        print("Do you want to show details of the above Models?")
        opt = input("Enter your Response (Yes/No) Only: ")

        if opt.lower() == 'yes' or opt.lower() == 'y':
            value = int(input("Choose model number from above list: "))

            if value == 1:
                print('''
                --- Ford EcoSport ---
                Engine: 1.5L Petrol / 1.5L Diesel
                Mileage: 17 - 21 km/l
                Price: ₹8 - ₹12 lakh
                Type: Compact SUV
                ''')
            elif value == 2:
                print('''
                --- Ford Endeavour ---
                Engine: 2.0L Diesel
                Mileage: 13 km/l
                Price: ₹30 - ₹37 lakh
                Type: Full-size SUV
                ''')
            elif value == 3:
                print('''
                --- Ford Figo ---
                Engine: 1.2L Petrol / 1.5L Diesel
                Mileage: 20 km/l
                Price: ₹6 - ₹8 lakh
                Type: Hatchback
                ''')
            elif value == 4:
                print('''
                --- Ford Aspire ---
                Engine: 1.2L Petrol / 1.5L Diesel
                Mileage: 21 km/l
                Price: ₹7 - ₹9 lakh
                Type: Compact Sedan
                ''')
            elif value == 5:
                print('''
                --- Ford Mustang ---
                Engine: 5.0L V8 Petrol
                Mileage: 8 km/l
                Price: ₹75 lakh - ₹1 crore
                Type: Sports Coupe
                ''')
            else:
                print("Invalid Input! Please enter a number between 1 and 5.")
        else:
            print("Thank You")


    def Company(self):
        print("********** Welcome to the Car Selection Where we find the Perfect car for you **********")
        print("\nPlease choose one brand from following list")
        print('''
        1. Hyundai
        2. Maruti
        3. Suzuki
        4. Nissan
        5. Honda
        6. BMW
        7. Mercedes
        8. Ford
        9. EXIT
        ''')

        while True:
            option = int(input("Choose a Brand OR press 9 for EXIT!!!: "))
            if option == 1:
                self.details1()
            elif option == 2:
                self.details2()
            elif option == 3:
                self.details3()
            elif option == 4:
                self.details4()
            elif option == 5:
                self.details5()
            elif option == 6:
                self.details6()
            elif option == 7:
                self.details7()
            elif option == 8:
                self.details8()
            elif option == 9:
                print("Thank You for using our services. We hope We find the best car for you!")
                break
            else:
                print("Invalid Option! Please try again.")


obj = carselection()
obj.Company()
# Out:
# ********** Welcome to the Car Selection Where we find the Perfect car for you **********
#
# Please choose one brand from following list
#
#         1. Hyundai
#         2. Maruti
#         3. Suzuki
#         4. Nissan
#         5. Honda
#         6. BMW
#         7. Mercedes
#         8. Ford
#         9. EXIT
# Choose a Brand OR press 9 for EXIT!!!:  1
# Great Choice!! For Brand: Hyundai
# You can go with the following car models for your selected brand
# -----------------------------------------------
#
#         1. Hyundai i20
#         2. Hyundai Creta
#         3. Hyundai Venue
#         4. Hyundai Verna
#         5. Hyundai Alcazar
#
# Do You want to show details of above Models:
# Enter your Response (Yes/No) Only:  yes
# Choose model number from above list:  5
#                 --- Hyundai Alcazar ---
#                 Engine: 2.0L Petrol / 1.5L Diesel
#                 Mileage: 17.5 km/l
#                 Price: ₹16 - ₹21 lakh
#                 Type: 7-Seater SUV
# ...
